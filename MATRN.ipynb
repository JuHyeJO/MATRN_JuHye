# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
 ls
# Out:
# sample_data/  test3/  test3.zip

# %%
import os
os.chdir('/gdrive/MyDrive/AI/MATRN')
# !pip install fastai==1.0.60
# !pip install tensorboardX
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 237.3/237.3 KB 14.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 355.2/355.2 KB 38.8 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for nvidia-ml-py3: filename=nvidia_ml_py3-7.352.0-py3-none-any.whl size=19190 sha256=beda5a7782dd9a76deed709820c3310e78e41ea9066edbb77b57e5f01ea137bd
#   Stored in directory: /root/.cache/pip/wheels/b9/b1/68/cb4feab29709d4155310d29a421389665dcab9eb3b679b527b
# Successfully built nvidia-ml-py3
# ...
#   Attempting uninstall: fastai
#     Found existing installation: fastai 2.7.10
#     Uninstalling fastai-2.7.10:
#       Successfully uninstalled fastai-2.7.10
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.4/125.4 KB 7.8 MB/s eta 0:00:00
# ...

# %%
! python /gdrive/MyDrive/AI/MATRN/main.py --config=/gdrive/MyDrive/AI/MATRN/configs/train_matrn.yaml \
--checkpoint /train-matrn_4_27000
# Out:
# ModelConfig(
# 	(0): dataset_case_sensitive = False
# 	(1): dataset_charset_path = data/charset_ko.txt
# 	(2): dataset_data_aug = True
# 	(3): dataset_eval_case_sensitive = False
# 	(4): dataset_image_height = 32
# 	(5): dataset_image_width = 128
# 	(6): dataset_max_length = 25
# 	(7): dataset_multiscales = False
# 	(8): dataset_num_workers = 0
# 	(9): dataset_one_hot_y = True
# 	(10): dataset_pin_memory = True
# 	(11): dataset_smooth_factor = 0.1
# 	(12): dataset_smooth_label = False
# 	(13): dataset_test_batch_size = 12
# 	(14): dataset_test_roots = ['/gdrive/MyDrive/AI/data_lmdb/validation']
# 	(15): dataset_train_batch_size = 12
# 	(16): dataset_train_roots = ['/gdrive/MyDrive/AI/data_lmdb/train']
# 	(17): dataset_use_sm = False
# 	(18): dataset_valid_batch_size = 12
# 	(19): dataset_valid_roots = ['/gdrive/MyDrive/AI/data_lmdb/validation']
# 	(20): global_name = train-matrn
# 	(21): global_phase = train
# 	(22): global_seed = None
# 	(23): global_stage = train-super
# ...

# %%
# char file 만들기
import pickle
with open('/gdrive/MyDrive/AI/data_jy/idx2char.dat', 'rb') as f:
    idx2char= pickle.load(f)

f = open("/gdrive/MyDrive/AI/MATRN/data/charset_ko.txt", 'w')
for i in range(1, len(idx2char.keys())):
    f.write(f"{i-1}\t{idx2char[i]}\n")
f.close()

# %%
import torch
temp = torch.load('/gdrive/MyDrive/AI/MATRN/pretrain/pretrain-vision-model/best-pretrain-vision-model.pth')

# %%
temp.keys()
# Out:
# dict_keys(['model', 'opt'])

# %%
! python /gdrive/MyDrive/AI/MATRN/demo.py --config /gdrive/MyDrive/AI/MATRN/configs/train_matrn.yaml \
--checkpoint /gdrive/MyDrive/AI/MATRN/results/train-matrn/best-valid-train-matrn.pth \
--input /content/test3
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#  65% 9439/14438 [1:11:25<37:24,  2.23it/s][2023-01-09 03:15:18,264 demo.py:112 INFO train-matrn] /content/test3/TEST_26937.png: 목욕
#  65% 9440/14438 [1:11:26<37:10,  2.24it/s][2023-01-09 03:15:18,713 demo.py:112 INFO train-matrn] /content/test3/TEST_26938.png: 구청
#  65% 9441/14438 [1:11:26<37:14,  2.24it/s][2023-01-09 03:15:19,187 demo.py:112 INFO train-matrn] /content/test3/TEST_26939.png: 그러민
#  65% 9442/14438 [1:11:27<37:54,  2.20it/s][2023-01-09 03:15:19,717 demo.py:112 INFO train-matrn] /content/test3/TEST_26940.png: 두다
#  65% 9443/14438 [1:11:27<39:46,  2.09it/s][2023-01-09 03:15:20,209 demo.py:112 INFO train-matrn] /content/test3/TEST_26941.png: 이분
#  65% 9444/14438 [1:11:28<40:05,  2.08it/s][2023-01-09 03:15:20,801 demo.py:112 INFO train-matrn] /content/test3/TEST_26942.png: 반장
#  65% 9445/14438 [1:11:28<42:51,  1.94it/s][2023-01-09 03:15:21,408 demo.py:112 INFO train-matrn] /content/test3/TEST_26943.png: 높다
# ...

# %%
file=open('/gdrive/MyDrive/손글씨공모전/data/log_demo_result.txt' ,'r')
output = file.read()
print(output)
file.close()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
print(output)

# %%
output
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
import sys
sys.stdout = open('/content/output.txt','w')
print(output)

# %%
data=pd.read_csv('/content/output.csv')

# %%
data
# Out:
#         /content/test/TEST_00000.png:      날말
# 0       /content/test/TEST_00001.png:      상활
# 1       /content/test/TEST_00002.png:   날아들이다
# 2       /content/test/TEST_00003.png:     바구니
# 3       /content/test/TEST_00004.png:       살
# 4       /content/test/TEST_00005.png:     빼놓다
# ...                                ...    ...
# 59677  /content/test2/TEST_74116.png:     재나다
# 59678  /content/test2/TEST_74117.png:      사무
# 59679  /content/test2/TEST_74118.png:    친절하다
# 59680  /content/test2/TEST_74119.png:       쪽
# 59681  /content/test2/TEST_74120.png:    부정하다
#
# [59682 rows x 2 columns]

# %%
data = pd.DataFrame()
